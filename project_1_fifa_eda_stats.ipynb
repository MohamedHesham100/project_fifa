# %% [markdown]
# ###
# Name : Mohamed Hesham El Nady.
#
#
# ID :21511127

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('fifa_eda_stats.csv')
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club    Value   Wage Preferred Foot  ...  Composure  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club    Value   Wage Preferred Foot  ...  Composure  \
# ...

# %%
df.head(10)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
# 5  183277          E. Hazard   27     Belgium       91         91
# 6  177003          L. Modrić   32     Croatia       91         91
# 7  176580          L. Suárez   31     Uruguay       91         91
# 8  155862       Sergio Ramos   32       Spain       91         91
# 9  200389           J. Oblak   25    Slovenia       90         93
#
#                   Club    Value   Wage Preferred Foot  ...  Marking  \
# 0         FC Barcelona  €110.5M  €565K           Left  ...     33.0
# 1             Juventus     €77M  €405K          Right  ...     28.0
# ...

# %%
df["newRC"] =df["Release Clause"].replace(["€"], [""], regex=True)
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club    Value   Wage Preferred Foot  ...  Marking  \
# ...

# %%
def represent(cell) :
    
    if type(cell) == str :
        if cell[-1]=="M" :
            return float(cell[:-1]) * 1000000.0
        elif cell[-1]== "K" :
            return float(cell[:-1])*1000.0
        else :
            return float(cell)
    else:
        return 0.0

# %%
df.newRC = df.newRC.apply(represent)

# %%
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club    Value   Wage Preferred Foot  ...  Marking  \
# ...

# %%
df.drop("Release Clause", axis = 1)
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club    Value   Wage Preferred Foot  ...  Composure  \
# ...

# %%
df.describe()
# Out:
#                   ID           Age       Overall     Potential  \
# count   18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299
# std     29965.244204      4.669943      6.908930      6.136496
# min        16.000000     16.000000     46.000000     48.000000
# 25%    200315.500000     21.000000     62.000000     67.000000
# 50%    221759.000000     25.000000     66.000000     71.000000
# 75%    236529.500000     28.000000     71.000000     75.000000
# max    246620.000000     45.000000     94.000000     95.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# std                    0.394031      0.660456      0.756164      15.947765
# min                    1.000000      1.000000      1.000000       1.000000
# ...

# %%
df.shape
# Out:
# (18207, 58)

# %%
def searchplayer(playername):
    return playername in df.Name.values

# %%
if (searchplayer("W. Rooney")):
    print("yes")
# Out:
# yes

# %% [markdown]
# ### Now use visualization

# %%
plt.hist(df.Overall) # histogram
plt.xticks(np.arange(40, 110, 5))
plt.yticks([0, 2, 10, 14, 20, 30, 1000, 2000, 3000, 4000, 5000, 6000])
plt.show()

# %%
df.Overall.min()
# Out:
# 46

# %%
df.Overall.max()
# Out:
# 94

# %%
maxx= df["Name"] [df.Overall >=90]
print(len(maxx))
maxx
# Out:
# 14
# 0              L. Messi
# 1     Cristiano Ronaldo
# 2             Neymar Jr
# 3                De Gea
# 4          K. De Bruyne
# 5             E. Hazard
# 6             L. Modrić
# 7             L. Suárez
# 8          Sergio Ramos
# 9              J. Oblak
# 10       R. Lewandowski
# 11             T. Kroos
# 12             D. Godín
# 13          David Silva
# Name: Name, dtype: object

# %%
ARG = df["Name"] [df.Nationality == "Argentina"] [df.Overall >=85]
ARG
# Out:
# 0        L. Messi
# 15      P. Dybala
# 23      S. Agüero
# 38     G. Higuaín
# 43      M. Icardi
# 89    N. Otamendi
# Name: Name, dtype: object

# %%
plt.figure(figsize= (8,8))
Name = df.Name[:10]
Overall = df.Overall[:10]
plt.xticks(np.arange(0,110,10))
plt.yticks()
plt.barh(Name,Overall )
# Out:
# <BarContainer object of 10 artists>

# %%
leftt= (df.loc[df["Preferred Foot"] == "Left"].count()[0]) / df.shape[0]*100
leftt
# Out:
# 23.12846707310375

# %%
right = df.loc[df["Preferred Foot"] == "Right"].count()[0]
right
# Out:
# 76.60789806118525

# %%
len(df.loc[df["Preferred Foot"] == "Left"])
# Out:
# 4211

# %%
right= (df.loc[df["Preferred Foot"] == "Right"].count()[0])
right
# Out:
# 13948

# %%
left = df.loc[df['Preferred Foot'] == "Left"].count()[0]
right = df.loc[df['Preferred Foot'] == 'Right'].count()[0]
plt.pie([left, right], labels=['left','right'] , autopct='%.2f%%')
plt.show()

# %%
# %matplotlib inline
left = df.loc[df['Preferred Foot'] == "Left"].count()[0]
right = df.loc[df['Preferred Foot'] == 'Right'].count()[0]
plt.bar(['left', 'right'],[left, right], width= .4)
plt.show()

# %%
# %matplotlib notebook
plt.style.use('dark_background')


maxcountries = df.Nationality.value_counts()[:12]
maxcountries= maxcountries.to_list()
print(maxcountries)

print(sum(maxcountries))

maxcountriesnames =df.Nationality.value_counts().index[:12]
maxcountriesnames =maxcountriesnames.to_list()

maxcountriesnames.append("Others")

allcountries = sum(maxcountries)
print(len(df))

others= sum(list(df.Nationality.value_counts())) - allcountries
maxcountries.append(others)
plt.pie(maxcountries, labels= maxcountriesnames, autopct= '%0.2f%%', radius= 1.4)
plt.show()
# Out:
# [1662, 1198, 1072, 937, 914, 827, 702, 618, 478, 453, 397, 392]
# 9650
# 18207
# <img src="data:image/png;base64,..." width="640.4166666666666">

# %%
df.Weight
# Out:
# 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 18202    134lbs
# 18203    170lbs
# 18204    148lbs
# 18205    154lbs
# 18206    176lbs
# Name: Weight, Length: 18207, dtype: object

# %%
df.Weight = [x.strip("lbs") if type (x) == str else x for x in df.Weight]
df.Weight
df.Weight[0]
# Out:
# '159'

# %%
plt.style.use('ggplot')
# %matplotlib inline
df.Weight = [int(x.strip('lbs')) if type(x)==str else x for x in df.Weight]

light = df.loc[df.Weight < 125].count()[0]
light_medium = df[(df.Weight >= 125) & (df.Weight < 150)].count()[0]
medium = df[(df.Weight >= 150) & (df.Weight < 175)].count()[0]
medium_heavy = df[(df.Weight >= 175) & (df.Weight < 200)].count()[0]
heavy = df[df.Weight >= 200].count()[0]

weights = [light,light_medium, medium, medium_heavy, heavy]
label = ['under 125', '125-150', '150-175', '175-200', 'over 200']
explode = (.4,.2,0,0,.4)

#plt.title('Weight of Professional Soccer Players (lbs)')

plt.pie(weights, labels=label, explode=explode, pctdistance=0.8,autopct='%.2f %%', radius=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Summary of Insights
#
# First, the number of rows and columns in the data set was determined, the data types for each column were determined, and missing values in each column were checked.
#
#
#
# I manipulated the letters of the release clause so that I could use its numbers in some analysis, so I created a function with a variable that replaces the million/thousand pounds. I also used regex.
#
# Then I calculated the basic statistics of the mean, median, mode, minimum and maximum for the FIFA players
#
# I then visualized the underlying data by creating a graph of the total players in FIFA, and using a horizontal bar for the top 10 players overall.
# Then I made a bar and pie chart between the two players, right footed and left footed, to calculate the percentage for each.
#
# I've created a pie chart to show the 10 countries with the highest number of players in FIFA.
# Then at the end I explained some of the weight of a professional football player
